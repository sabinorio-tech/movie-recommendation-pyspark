# %% [markdown]
# # Test `recommend_similar_movies`
#
# This notebook imports the reusable recommendation function from `src` and tests it with an example movie.

# %%
import sys
from pathlib import Path

repo_root = Path.cwd()
if not (repo_root / "src").exists():
    repo_root = repo_root.parent

sys.path.append(str(repo_root))

# %%
from src.recommend import recommend_similar_movies

# %%
recommend_similar_movies("Interstellar", top_n=10)
